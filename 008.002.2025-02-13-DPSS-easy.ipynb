# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from LIMxCMBL.cross_spectrum import *
from LIMxCMBL.init import *
from LIMxCMBL.noise import *
from LIMxCMBL.kernels import *

# %%
from scipy.signal.windows import dpss

# %%
from tqdm import tqdm

# %%
# CCAT-prime
zmin = 3.5
zmax = 8.1
chimin = ccl.comoving_angular_distance(cosmo, 1/(1+zmin))
chimax = ccl.comoving_angular_distance(cosmo, 1/(1+zmax))
window = np.where((chis_resample > chimin) & (chis_resample < chimax))[0]

_chimin, _chimax = chis_resample[window][0], chis_resample[window][-1]


Lambdas = np.logspace(-5, 0, 50)
Lambda = Lambdas[13]
print(Lambda)
chis_resample_len = 13

oup_fname = '/scratch/users/delon/LIMxCMBL/eHIeHI/zmin_%.5f_zmax_%.5f_Lambda_%.5e_chi_sample_2e%d'%(zmin, zmax, Lambda,chis_resample_len)
eIeI = np.load(oup_fname + 'eIeI.npy')
eIeLO = np.load(oup_fname + 'eIeLO.npy' ,)
eLOeI = np.load(oup_fname + 'eLOeI.npy' , )
eLOeLO = np.load(oup_fname + 'eLOeLO.npy', )
eHIeHI = eIeI + eLOeLO - eIeLO - eLOeI

IHi_kappa_fname = '/scratch/users/delon/LIMxCMBL/IHiKappa/zmin_%.5f_zmax_%.5f_Lambda_%.5f_chi_sample_2e%d.npy'%(zmin, zmax, Lambda,chis_resample_len)
IHi_kappa = np.load(IHi_kappa_fname) #[kJy/sr Mpc]
IHi_kappa_windowed = IHi_kappa[:, window].astype(np.float64)
# Out:
# 0.00021209508879201905

# %%
dchi = np.mean(np.diff(chis_resample))

# %% [markdown]
# # trying to figure out dpss

# %%
_LAMBDA = Lambda

# %%
M = len(eHIeHI)
NW = (_chimax - _chimin) * _LAMBDA / (2 * np.pi) 
   # window lenght * band width

v = dpss(M = M,
         NW = NW,
         Kmax = 30, sym = False)

v_k = np.fft.rfft(v)
k = 2*np.pi*np.fft.rfftfreq(len(v[0]), d = dchi)

# %%
plt.plot(chis_resample[window], v.T/np.max(v, axis=1))
# Out:
# [<matplotlib.lines.Line2D at 0x7faa5c03a2e0>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a310>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a400>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a4f0>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a5e0>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a6d0>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a7c0>,
#  <matplotlib.lines.Line2D at 0x7faa5c03a8b0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0a9250>,
#  <matplotlib.lines.Line2D at 0x7faa5c0a9100>,
#  <matplotlib.lines.Line2D at 0x7faa5c03aa60>,
#  <matplotlib.lines.Line2D at 0x7faa5c03ab50>,
#  <matplotlib.lines.Line2D at 0x7faa5c03ac40>,
#  <matplotlib.lines.Line2D at 0x7faa5c03ad30>,
#  <matplotlib.lines.Line2D at 0x7faa5c03ae20>,
#  <matplotlib.lines.Line2D at 0x7faa5c03af10>,
#  <matplotlib.lines.Line2D at 0x7faa5c047040>,
#  <matplotlib.lines.Line2D at 0x7faa5c047130>,
#  <matplotlib.lines.Line2D at 0x7faa5c047220>,
#  <matplotlib.lines.Line2D at 0x7faa5c047310>,
#  <matplotlib.lines.Line2D at 0x7faa5c047400>,
#  <matplotlib.lines.Line2D at 0x7faa5c0474f0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0475e0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0476d0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0477c0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0478b0>,
#  <matplotlib.lines.Line2D at 0x7faa5c0479a0>,
#  <matplotlib.lines.Line2D at 0x7faa5c047a90>,
#  <matplotlib.lines.Line2D at 0x7faa5c047b80>,
#  <matplotlib.lines.Line2D at 0x7faa5c047c70>]

# %%
plt.plot(k, np.abs(v_k.T))

plt.axvline(_LAMBDA, c='k')
plt.xscale('log')
plt.loglog()
# Out:
# []

# %%
plt.imshow(eIeLO + eLOeI)

# %%
plt.imshow((eIeLO + eLOeI) * chis_resample[window] ** 2)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(eHIeHI * chis_resample[window] ** 2)
print(eigenvalues.shape, eigenvectors.shape)
# Out:
# (1652,) (1652, 1652)

# %%
idx_sort = np.argsort(eigenvalues)
eigenvalues = eigenvalues[idx_sort][::-1]
eigenvectors = eigenvectors[idx_sort][::-1]

# %%
plt.plot(chis_resample[window], eigenvectors.T[2])
plt.plot(chis_resample[window],v[2])

# %%
plt.plot(chis_resample[window], IHi_kappa_windowed.T);

# %%
IHi_kappa_windowed_k = np.fft.rfft(IHi_kappa_windowed)

# %%
plt.plot(k, np.abs(IHi_kappa_windowed_k.T))
plt.axvline(Lambda)
plt.loglog()
# Out:
# []

# %% [markdown]
# # computing snr per mode

# %%
L = np.linalg.cholesky(eHIeHI)
y = np.linalg.solve(L, IHi_kappa_windowed.T)
x = np.linalg.solve(L.T, y)
res1 = np.einsum('ij, ji->i', IHi_kappa_windowed, x)

# %%
L = np.linalg.cholesky(eHIeHI * chis_resample[window] ** 2)
y = np.linalg.solve(L, IHi_kappa_windowed.T )
x = np.linalg.solve(L.T, y) 
res8 = np.einsum('ij, ji->i', chis_resample[window] ** 2 * IHi_kappa_windowed, x )

# %%
from scipy.signal.windows import dpss


def tmp(cov = eHIeHI, factor = 2):
    
    M = len(cov)
    NW = (_chimax - _chimin) * Lambda / (2 * np.pi)    
    Kmax = max(1, int(min(factor * NW * M, M)))
    
    print(M, Kmax)
    v = dpss(M = M,
             NW = NW,
             Kmax = Kmax)
    print(v.shape, cov.shape, v.T.shape)
    cov_dpss = v @ cov @ v.T
    cov_dpss_inv = np.diag(1.0 / np.diag(cov_dpss))
    cov_inv  = v.T @ cov_dpss_inv @ v
    return np.einsum('ij, jk, ki->i', IHi_kappa_windowed, cov_inv, IHi_kappa_windowed.T)

# %%
plt.figure(dpi = 300)
plt.plot(ells, ells**2 * res1, 'k')
plt.plot(ells, ells**2 * res8, 'r--')

plt.legend(frameon=False)
plt.xscale('log')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
cov = eHIeHI * chis_resample[window] ** 2
factor = 2
M = len(cov)
NW = (_chimax - _chimin) * Lambda / (2 * np.pi)    
Kmax = max(1, int(min(factor * NW * M, M)))

print(M, Kmax)
v = dpss(M = M,
         NW = NW,
         Kmax = Kmax)
print(v.shape, cov.shape, v.T.shape)
cov_dpss = v @ cov @ v.T
cov_dpss_inv = np.diag(1.0 / np.diag(cov_dpss))
cov_inv  = v.T @ cov_dpss_inv @ v
res2 = np.einsum('ij, jk, ki->i', chis_resample[window] ** 2 * IHi_kappa_windowed, cov_inv, IHi_kappa_windowed.T)
# Out:
# 1652 246
# (246, 1652) (1652, 1652) (1652, 246)

# %%
plt.figure(dpi = 300)
plt.plot(ells, ells**2 * res1, 'k')
plt.plot(ells, ells**2 * res2, 'r--')
plt.plot(ells, ells**2 * res8, 'b-.')

plt.legend(frameon=False)
plt.xscale('log')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
