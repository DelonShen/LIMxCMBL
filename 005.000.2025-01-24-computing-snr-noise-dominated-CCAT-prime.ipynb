# %%
from LIMxCMBL.init import *
from LIMxCMBL.noise import *

# %%
# CCAT-Prime
zmin = 3.5
zmax = 8.1

Omega_field = 8 #deg^2

chimin = ccl.comoving_angular_distance(cosmo, 1/(1+zmin))
chimax = ccl.comoving_angular_distance(cosmo, 1/(1+zmax))

Pei = 5.7e4 #Jy / sr CCAT-prime
Lambda = 0.01 # 1 / Mpc, usual cut for HI

# %%
dchi = np.mean(np.diff(chibs))

# %%
IHi_kappa_fname = '/scratch/users/delon/LIMxCMBL/IHiKappa/zmin_%.5f_zmax_%.5f_Lambda_%.5f.npy'%(zmin, zmax, Lambda)
print(IHi_kappa_fname)
IHi_kappa = np.load(IHi_kappa_fname)
# Out:
# /scratch/users/delon/LIMxCMBL/IHiKappa/zmin_3.50000_zmax_8.10000_Lambda_0.01000.npy

# %%
(chimax - chimin)//dchi
# Out:
# 51.0

# %%
eIeI, eLOeLO, eIeLO, eLOeI = get_eHIeHI(Pei, chimin, chimax, dchi, Lambda, elems = True)
eHIeHI = eIeI + eLOeLO - eIeLO - eLOeI
# Out:
# computing eIeI
# computing eIeLO
# computing eLOeI
# computing eLOeLO
# 100%|██████████| 256/256 [00:03<00:00, 71.86it/s]

# %%
from LIMxCMBL.kernels import get_f_Kkappa
f_WkD = get_f_Kkappa()

from LIMxCMBL.cross_spectrum import *
ClKK = d_chib_integral(f_WkD, f_WkD)


# beam=1.4, noise=7
from scipy.interpolate import interp1d
N0_ells = np.logspace(1, np.log10(5000), 500)
with open('LIMxCMBL/N0.npy', 'rb') as f:
    N0 = np.load(f)
    
f_N0 = interp1d(x = N0_ells, y = N0)

    
plt.plot(ells, ClKK)
plt.plot(ells, f_N0(ells))
plt.loglog()
# Out:
# []

# %%
vminmax = np.max(np.abs(eHIeHI))
plt.figure(figsize=(3.5,3.5), dpi=300, facecolor='w',)

# figure out bounds
 
# plot data
plt.imshow(eHIeHI, 
           origin='lower',
          cmap = 'seismic',
          vmin = -vminmax,
          vmax =  vminmax,
          extent=[chibs[0], chibs[-1], chibs[0], chibs[-1]])

plt.colorbar()
plt.xlabel(r'$\chi$')
plt.ylabel(r"$\chi'$")
plt.title(r"$\langle \epsilon^{I,{\sf HI}}_\ell(\chi) \epsilon^{I, {\sf Hi}}_{-\ell}(\chi')\rangle'$")
# Out:
# Text(0.5, 1.0, "$\\langle \\epsilon^{I,{\\sf HI}}_\\ell(\\chi) \\epsilon^{I, {\\sf Hi}}_{-\\ell}(\\chi')\\rangle'$")

# %% [markdown]
# # Naive Noise Dominated

# %%
inv_eHIeHI = np.linalg.inv(eHIeHI)
vminmax = np.max(np.abs(inv_eHIeHI))
plt.figure(figsize=(3.5,3.5), dpi=300, facecolor='w',)

# figure out bounds
 
# plot data
plt.imshow(inv_eHIeHI, 
           origin='lower',
          cmap = 'seismic',
          vmin = -vminmax,
          vmax =  vminmax,
          extent=[chibs[0], chibs[-1], chibs[0], chibs[-1]])

plt.colorbar()
plt.xlabel(r'$\chi$')
plt.ylabel(r"$\chi'$")
plt.title(r"inverted $\langle \epsilon^{I,{\sf HI}}_\ell(\chi) \epsilon^{I, {\sf Hi}}_{-\ell}(\chi')\rangle'$")
# Out:
# Text(0.5, 1.0, "inverted $\\langle \\epsilon^{I,{\\sf HI}}_\\ell(\\chi) \\epsilon^{I, {\\sf Hi}}_{-\\ell}(\\chi')\\rangle'$")

# %%
eHIeHI.shape
# Out:
# (256, 256)

# %%
np.linalg.cond(eHIeHI)
# Out:
# 7.316307288338935e+20

# %%
inv_eHIeHI = np.linalg.inv(eHIeHI)
unstable_SNR2_per_mode = np.einsum('ij, jk, ki-> i', IHi_kappa, inv_eHIeHI, IHi_kappa.T)
unstable_SNR2_per_mode *= 1/(ClKK + f_N0(ells)) * dchi**2
plt.plot(ells, unstable_SNR2_per_mode)
plt.xscale('log')

# %%
eHIeHI_64 = eHIeHI.astype(np.float64)
IHi_kappa_64 = IHi_kappa.astype(np.float64)

intermediate = np.linalg.solve(eHIeHI_64, IHi_kappa_64.T)
SNR2_per_mode = np.sum(IHi_kappa_64 * intermediate.T, axis=1)
SNR2_per_mode *= 1/(ClKK + f_N0(ells)) * dchi**2

# %%
plt.plot(ells, SNR2_per_mode, 'k')
plt.plot(ells, unstable_SNR2_per_mode, 'r--')

plt.xscale('log')

# %%
plt.plot(ells, ells**4 * SNR2_per_mode, 'r--')
plt.axhline(0)
plt.xscale('log')

# %%
tmp = eIeI*(ClKK[42] + f_N0(ells[42])) + IHi_kappa[42].reshape(-1, 1) * IHi_kappa[42].reshape( 1, -1)
tmp = tmp.astype(np.float64)

# %%
import numpy as np

# Basic matrix properties
print("Shape:", tmp.shape)
print("Data type:", tmp.dtype)
print("Number of non-zero elements:", np.count_nonzero(tmp))
print("Sparsity: {:.2%}".format(1 - np.count_nonzero(tmp)/(256*256)))

# Value ranges
print("\nValue ranges:")
print("Maximum absolute value:", np.abs(tmp).max())
print("Minimum non-zero absolute value:", np.abs(tmp[np.abs(tmp) > 0]).min())
print("Mean of non-zero absolute values:", np.abs(tmp[np.abs(tmp) > 0]).mean())

# Distribution of values
hist, bins = np.histogram(np.log10(np.abs(tmp[np.abs(tmp) > 0])), bins=20)
print("\nHistogram of log10 of non-zero absolute values:")
for i in range(len(hist)):
    print(f"10^{bins[i]:.1f} to 10^{bins[i+1]:.1f}: {hist[i]}")

# Eigenvalue analysis
eigenvals = np.linalg.eigvals(tmp)
print("\nEigenvalue ranges:")
print("Largest eigenvalue magnitude:", np.abs(eigenvals).max())
print("Smallest eigenvalue magnitude:", np.abs(eigenvals[np.abs(eigenvals) > 0]).min())

# Check symmetry
is_symmetric = np.allclose(tmp, tmp.T, rtol=1e-10)
print("\nIs matrix symmetric?", is_symmetric)
# Out:
# Shape: (256, 256)
# Data type: float64
# Number of non-zero elements: 65536
# Sparsity: 0.00%
#
# Value ranges:
# Maximum absolute value: 5.572988172305306e-12
# Minimum non-zero absolute value: 2.5262762011843612e-26
# Mean of non-zero absolute values: 3.3796930856696886e-15
#
# Histogram of log10 of non-zero absolute values:
# 10^-25.6 to 10^-24.9: 1
# 10^-24.9 to 10^-24.2: 18
# 10^-24.2 to 10^-23.4: 74
# 10^-23.4 to 10^-22.7: 443
# 10^-22.7 to 10^-22.0: 1405
# 10^-22.0 to 10^-21.3: 4628
# 10^-21.3 to 10^-20.6: 12768
# 10^-20.6 to 10^-19.9: 16499
# 10^-19.9 to 10^-19.1: 6849
# 10^-19.1 to 10^-18.4: 7455
# 10^-18.4 to 10^-17.7: 7717
# 10^-17.7 to 10^-17.0: 4489
# 10^-17.0 to 10^-16.3: 1280
# 10^-16.3 to 10^-15.6: 1064
# 10^-15.6 to 10^-14.8: 652
# 10^-14.8 to 10^-14.1: 142
# 10^-14.1 to 10^-13.4: 0
# 10^-13.4 to 10^-12.7: 0
# 10^-12.7 to 10^-12.0: 0
# 10^-12.0 to 10^-11.3: 52
#
# Eigenvalue ranges:
# Largest eigenvalue magnitude: 5.573328215756279e-12
# Smallest eigenvalue magnitude: 2.471409039644472e-41
#
# Is matrix symmetric? True

# %% [markdown]
# # no filtering snr per mode

# %%
from  LIMxCMBL.kernels import *
f_KLIM   = get_f_KI()
f_Kkappa = get_f_Kkappa()

f_KLIM_windowed = apply_window(f_K = f_KLIM,
                               chimin = chimin,
                               chimax = chimax)
I_kappa = d_delta_integral(f_KLIM_windowed, f_Kkappa)

# %%
_vv = np.max(np.abs(I_kappa))
plt.imshow(I_kappa, vmin = -_vv, vmax = _vv, cmap='seismic')
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Casting input data from float128 to float64 for imshow.
#   func(*args, **kwargs)
# /share/software/user/open/py-jupyter/1.0.0_py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:134: UserWarning: Casting input data from float128 to float64 for imshow.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.imshow(IHi_kappa, vmin = -_vv, vmax = _vv, cmap='seismic')

# %%
np.allclose(np.diag(np.diag(eIeI)), eIeI, atol = 0.0, rtol = 1e-8)
# Out:
# True

# %%
SNR2_per_mode_no_cut = np.zeros_like(ells)
#becuase no cut makes everything diagonal we can do a direct sum

for chib_idx in range(len(chibs)):
    chi = chibs[chib_idx]
    if(chi < chimin or chi > chimax):
        continue
    SNR2_per_mode_no_cut += I_kappa.T[chib_idx]**2 / (Pei/chi**2) * dchi
SNR2_per_mode_no_cut *= 1/(ClKK + f_N0(ells))

# %%
SNR2_per_mode_no_cut_but_Hi_data = np.zeros_like(ells)
#becuase no cut makes everything diagonal we can do a direct sum

for chib_idx in range(len(chibs)):
    chi = chibs[chib_idx]
    if(chi < chimin or chi > chimax):
        continue
    SNR2_per_mode_no_cut_but_Hi_data += IHi_kappa.T[chib_idx]**2  / (Pei/chi**2) * dchi
SNR2_per_mode_no_cut_but_Hi_data *= 1/(ClKK + f_N0(ells))

# %%
plt.figure(facecolor = 'w')
plt.plot(ells, SNR2_per_mode_no_cut, 'k', label='unfiltered data')
plt.plot(ells, SNR2_per_mode_no_cut_but_Hi_data, 'r', label='high passed data')

plt.xscale('log')
plt.xlabel('ells')
plt.ylabel('SNR2 per mode for CCAT-prime')
plt.title('$\Lambda=%.2f$, If the LIM noise doesnt get filtered'%(Lambda))
plt.legend(frameon=False)
